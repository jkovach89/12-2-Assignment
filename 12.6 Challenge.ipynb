# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt
# %matplotlib inline
data = pd.read_csv('/Users/JKovach/Downloads/APCspend.csv', encoding = 'ISO-8859-1')
print(data)
# Out:
#                             PMID/PMCID  \
# 0                                  NaN
# 1                           PMC3679557
# 2                23043264  PMC3506128
# 3                  23438330 PMC3646402
# 4                 23438216 PMC3601604
# 5                           PMC3579457
# 6                           PMC3709265
# 7                 23057412 PMC3495574
# 8                    PMCID: PMC3780468
# 9                    PMCID: PMC3621575
# 10                   PMCID: PMC3739413
# 11                   PMCID: PMC3530961
# 12                   PMCID: PMC3624797
# 13                          PMC3413243
# 14                          PMC3694353
# 15                          PMC3572711
# 16                            22610094
# 17                   PMCID: PMC3586974
# 18        23455506  PMCID: PMC3607399
# 19          PMID: 24015914 PMC3833349
# 20                       : PMC3805332
# 21                                 NaN
# 22            PMCID:\n    PMC3656742\n
# ...

# %%
data['clean_title'] = data['Journal title'].str.lower()
#data['Journal title'].value_counts()
data['clean_title'].value_counts()
# Out:
# plos one                                                    190
# journal of biological chemistry                              53
# neuroimage                                                   29
# plos pathogens                                               24
# plos genetics                                                24
# nucleic acids research                                       23
# proceedings of the national academy of sciences              20
# plos neglected tropical diseases                             20
# nature communications                                        19
# human molecular genetics                                     19
# brain                                                        14
# bmc public health                                            14
# movement disorders                                           13
# developmental cell                                           12
# biochemical journal                                          12
# ...

# %%
data['pound_clean'] = data['COST (£) charged to Wellcome (inc VAT when charged)'].str.replace('£','')
data['cost'] = data['pound_clean'].str.replace('$','')
data_clean = data[data.cost != '999999']
data_clean['cost_float'] = data_clean['cost'].apply(lambda x: float(x))
print(np.mean(data_clean['clean_cost']))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /miniconda3/lib/python3.7/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     126                 else:
# --> 127                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     128             except Exception:
#
# /miniconda3/lib/python3.7/site-packages/pandas/core/nanops.py in nanmean(values, axis, skipna, mask)
#     478     count = _get_counts(mask, axis, dtype=dtype_count)
# --> 479     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     480
#
# /miniconda3/lib/python3.7/site-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial)
#      35          initial=_NoValue):
# ---> 36     return umr_sum(a, axis, dtype, out, keepdims, initial)
#      37
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
#
# ...
